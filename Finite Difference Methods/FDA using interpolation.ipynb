# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Finite Difference Equations using Interpolation
#
# One of the well-known methods for interpolation is lagrange interpolation. Suppose that the function that we want to calculate its derivitive is define on discrete points. We can take every n point of that function and fit a polynomial with degree (n-1) to that. Then we can calculate the derivitive of polynomail analyticly.
#
# See the following example:

# %% [markdown]
# ![FDA%20with%20Lagrange%20interpolation-1.jpg](attachment:FDA%20with%20Lagrange%20interpolation-1.jpg)

# %% [markdown]
# ![FDA%20with%20Lagrange%20interpolation-2.jpg](attachment:FDA%20with%20Lagrange%20interpolation-2.jpg)
