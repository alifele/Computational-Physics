# %%
import numpy as np
from numpy import genfromtxt
import matplotlib.pyplot as plt
import pandas as pd


# %matplotlib notebook

# %%
## The following data set is generated by the cpp code present in this folder
path = "/home/BCCRC.CA/aparanj/TRASH/LogisticMap/cmake-build-debug/data.csv"

## This file is the data which is arranged in the following format:
'''

r1,x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,...
r2,x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,...
r3,x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,...
r4,x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,...
r5,x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,...
.
.
rn,x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,...
'''
# Out:
# '\n\nr1,x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,...\nr2,x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,...\nr3,x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,...\nr4,x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,...\nr5,x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,...\n.\n.\nrn,x0,x1,x2,x3,x4,x5,x6,x7,x8,x9,...\n'

# %%
df = pd.read_csv (path)

# %%
mydata = df.to_numpy()

# %%
df = 0

# %%
mydata.shape
# Out:
# (599999, 502)

# %%
mydata
# Out:
# array([[3.4     , 0.842146, 0.451983, ..., 0.      , 0.      ,      nan],
#        [3.4     , 0.842146, 0.451983, ..., 0.      , 0.      ,      nan],
#        [3.4     , 0.842146, 0.451982, ..., 0.      , 0.      ,      nan],
#        ...,
#        [3.7     , 0.336806, 0.82646 , ..., 0.      , 0.      ,      nan],
#        [3.7     , 0.328777, 0.816525, ..., 0.      , 0.      ,      nan],
#        [3.7     , 0.266607, 0.723453, ..., 0.      , 0.      ,      nan]])

# %%
plt.figure()
a = plt.plot(mydata[:,1:32])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure(figsize=(10,8))
i = 50
dlist = [4,8,256]
start = 300000
#difference = 147000
difference = 100000
end = start + difference

for d in dlist:
    plt.plot(mydata[start:end,0], mydata[start:end,i+d]/mydata[start:end,i],label=d)
    #plt.scatter(mydata[start:end,0], mydata[start:end,i+d]/mydata[start:end,i], c=mydata[start:end,0],marker='o',s=5)
#plt.colorbar()
print(mydata[start,0])
plt.grid()
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# 3.55

# %%
plt.figure(figsize=(10,8))
i = 50
dList = [8]
start = 106000
#difference = 147000
difference = 500000
end = start + difference

end = start + difference
for d in dList:
    plt.scatter(mydata[start:end,i], mydata[start:end,i+d]/mydata[start:end,i], c=mydata[start:end,0],marker='o',s=5
               )
plt.colorbar()
print(mydata[start,0])
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# 3.453

# %%
plt.figure()
plt.imshow(mydata[start:end,i:i+d],aspect='auto')
# Out:
# <img src="data:image/png;base64,..." width="966">

# %%
plt.figure(figsize=(10,8))
plt.plot(mydata[start:end,i])
plt.plot(mydata[start:end,i+d])
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
### TEsts

# %%
plt.figure()
plt.plot(mydata[:400000,1],label='1')
plt.plot(mydata[:400000,2],label='2')
plt.plot(mydata[:400000,3],label='3')
plt.plot(mydata[:400000,4],label='4')
plt.plot(mydata[:400000,5],label='5')
plt.plot(mydata[:400000,6],label='6')

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(mydata[:,:-1].mean(axis=1))
# Out:
# <img src="data:image/png;base64,..." width="911">

# %%
mydata[start:end,1:5].shape
# Out:
# (493999, 4)

# %%
mydata.mean(axis=1)
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])
